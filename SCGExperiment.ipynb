# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
import sys
sys.path.append('/content/drive/MyDrive/repos/l2hmc')
# Out:
# Mounted at /content/drive

# %%
# %tensorflow_version 1.x
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# TensorFlow 1.x selected.

# %%
from utils.func_utils import accept, jacobian, autocovariance, get_log_likelihood, \
    get_data, binarize, normal_kl, acl_spectrum, ESS
from utils.distributions import Gaussian, GMM, GaussianFunnel, gen_ring
from utils.layers import Linear, Sequential, Zip, Parallel, ScaleTanh
from utils.dynamics import Dynamics
from utils.sampler import propose
from utils.notebook_utils import get_hmc_samples

# %% [markdown]
# ## Network architecture
#
# We define the network architecture for our L2HMC network. We first embed the first two variables ($\{x, \partial_x U\}$ or $\{v, x_m\}$) as well as the time, formatted as $\tau(t) = \left(\cos(\frac{2\pi t}{M}), \sin(\frac{2\pi t}{M})\right)$. They are forwarded through an MLP and then produce $S, T$ and $Q$.

# %%
def network(x_dim, scope, factor):
    with tf.variable_scope(scope):
        net = Sequential([
            Zip([
                Linear(x_dim, 10, scope='embed_1', factor=1.0 / 3),
                Linear(x_dim, 10, scope='embed_2', factor=factor * 1.0 / 3),
                Linear(2, 10, scope='embed_3', factor=1.0 / 3),
                lambda _: 0.,
            ]),
            sum,
            tf.nn.relu,
            Linear(10, 10, scope='linear_1'),
            tf.nn.relu,
            Parallel([
                Sequential([
                    Linear(10, x_dim, scope='linear_s', factor=0.001), 
                    ScaleTanh(x_dim, scope='scale_s')
                ]),
                Linear(10, x_dim, scope='linear_t', factor=0.001),
                Sequential([
                    Linear(10, x_dim, scope='linear_f', factor=0.001),
                    ScaleTanh(x_dim, scope='scale_f'),
                ])
            ])  
        ])
        
    return net

# %% [markdown]
# ## Distribution
#
# We define our energy function. It is a Gaussian distribution with zero mean. The covariance is a $\pi/4$ rotation of the eigenvalues $[100, 10^{-1}]$. We set up our dynamics which take as input our energy function, the number of time step of our operator, the (learnable) step-size and our architecture.

# %%
x_dim = 2
mu = np.zeros(2,)
cov = np.array([[50.05, -49.95], [-49.95, 50.05]])

distribution = Gaussian(mu, cov)
dynamics = Dynamics(x_dim, distribution.get_energy_function(), T=10, eps=0.1, net_factory=network)
# Out:
# 9.999999999999705 float64
# WARNING:tensorflow:From /content/drive/MyDrive/repos/l2hmc/utils/dynamics.py:47: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/repos/l2hmc/utils/dynamics.py:50: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/repos/l2hmc/utils/dynamics.py:52: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/MyDrive/repos/l2hmc/utils/layers.py:34: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %% [markdown]
# We can directly sample from this distribution and plot it for sanity-check.

# %%
S = distribution.get_samples(200)
plt.title('Strongly Correlated Gaussian (SCG)')
plt.scatter(S[:, 0], S[:, 1])
plt.show()

# %% [markdown]
# We set up the loss on both $p(\xi)$ (here `x`) and $q(\xi)$ (here `z`). We then train with Adam with a learning rate of $10^{-3}$.

# %%
x = tf.placeholder(tf.float32, shape=(None, x_dim))
z = tf.random_normal(tf.shape(x))

Lx, _, px, output = propose(x, dynamics, do_mh_step=True)
Lz, _, pz, _ = propose(z, dynamics, do_mh_step=False)

loss = 0.

v1 = (tf.reduce_sum(tf.square(x - Lx), axis=1) * px) + 1e-4
v2 = (tf.reduce_sum(tf.square(z - Lz), axis=1) * pz) + 1e-4
scale = 0.1

loss += scale * (tf.reduce_mean(1.0 / v1) + tf.reduce_mean(1.0 / v2))
loss += (- tf.reduce_mean(v1) - tf.reduce_mean(v2)) / scale
# Out:
# WARNING:tensorflow:From /content/drive/MyDrive/repos/l2hmc/utils/sampler.py:34: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/repos/l2hmc/utils/distributions.py:32: The name tf.diag_part is deprecated. Please use tf.linalg.tensor_diag_part instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/repos/l2hmc/utils/dynamics.py:309: The name tf.is_finite is deprecated. Please use tf.math.is_finite instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/repos/l2hmc/utils/dynamics.py:309: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
global_step = tf.Variable(0., name='global_step', trainable=False)
learning_rate = tf.train.exponential_decay(1e-3, global_step, 1000, 0.96, staircase=True)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss, global_step=global_step)

# %% [markdown]
# The training loop described in Algorithm $1$.

# %%
n_steps = 5000
n_samples = 200

samples = np.random.randn(n_samples, x_dim)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for t in range(n_steps):
    _, loss_, samples, px_, lr_ = sess.run([
        train_op,
        loss,
        output[0],
        px,
        learning_rate,
    ], {x: samples})

    if t % 100 == 0:
        print('Step: %d / %d, Loss: %.2e, Acceptance sample: %.2f, LR: %.5f' % (t, n_steps, loss_, np.mean(px_), lr_))
# Out:
# Step: 0 / 5000, Loss: -5.68e+01, Acceptance sample: 0.83, LR: 0.00100
# Step: 100 / 5000, Loss: -2.42e+02, Acceptance sample: 0.57, LR: 0.00100
# Step: 200 / 5000, Loss: -6.08e+02, Acceptance sample: 0.45, LR: 0.00100
# Step: 300 / 5000, Loss: -4.20e+03, Acceptance sample: 0.34, LR: 0.00100
# Step: 400 / 5000, Loss: -6.33e+03, Acceptance sample: 0.34, LR: 0.00100
# Step: 500 / 5000, Loss: -5.46e+03, Acceptance sample: 0.41, LR: 0.00100
# Step: 600 / 5000, Loss: -7.45e+03, Acceptance sample: 0.40, LR: 0.00100
# Step: 700 / 5000, Loss: -7.96e+03, Acceptance sample: 0.39, LR: 0.00100
# Step: 800 / 5000, Loss: -8.44e+03, Acceptance sample: 0.44, LR: 0.00100
# Step: 900 / 5000, Loss: -7.20e+03, Acceptance sample: 0.41, LR: 0.00100
# Step: 1000 / 5000, Loss: -8.74e+03, Acceptance sample: 0.44, LR: 0.00096
# Step: 1100 / 5000, Loss: -9.20e+03, Acceptance sample: 0.46, LR: 0.00096
# Step: 1200 / 5000, Loss: -9.49e+03, Acceptance sample: 0.41, LR: 0.00096
# Step: 1300 / 5000, Loss: -7.85e+03, Acceptance sample: 0.45, LR: 0.00096
# Step: 1400 / 5000, Loss: -8.54e+03, Acceptance sample: 0.35, LR: 0.00096
# Step: 1500 / 5000, Loss: -8.38e+03, Acceptance sample: 0.43, LR: 0.00096
# Step: 1600 / 5000, Loss: -8.50e+03, Acceptance sample: 0.43, LR: 0.00096
# Step: 1700 / 5000, Loss: -9.15e+03, Acceptance sample: 0.45, LR: 0.00096
# Step: 1800 / 5000, Loss: -8.09e+03, Acceptance sample: 0.39, LR: 0.00096
# Step: 1900 / 5000, Loss: -1.04e+04, Acceptance sample: 0.42, LR: 0.00096
# Step: 2000 / 5000, Loss: -1.11e+04, Acceptance sample: 0.43, LR: 0.00092
# Step: 2100 / 5000, Loss: -8.89e+03, Acceptance sample: 0.51, LR: 0.00092
# Step: 2200 / 5000, Loss: -9.79e+03, Acceptance sample: 0.41, LR: 0.00092
# Step: 2300 / 5000, Loss: -9.90e+03, Acceptance sample: 0.42, LR: 0.00092
# Step: 2400 / 5000, Loss: -8.59e+03, Acceptance sample: 0.43, LR: 0.00092
# Step: 2500 / 5000, Loss: -1.03e+04, Acceptance sample: 0.42, LR: 0.00092
# Step: 2600 / 5000, Loss: -1.01e+04, Acceptance sample: 0.46, LR: 0.00092
# Step: 2700 / 5000, Loss: -9.65e+03, Acceptance sample: 0.44, LR: 0.00092
# Step: 2800 / 5000, Loss: -9.42e+03, Acceptance sample: 0.36, LR: 0.00092
# Step: 2900 / 5000, Loss: -1.06e+04, Acceptance sample: 0.46, LR: 0.00092
# Step: 3000 / 5000, Loss: -9.67e+03, Acceptance sample: 0.40, LR: 0.00088
# Step: 3100 / 5000, Loss: -1.14e+04, Acceptance sample: 0.44, LR: 0.00088
# Step: 3200 / 5000, Loss: -9.75e+03, Acceptance sample: 0.42, LR: 0.00088
# Step: 3300 / 5000, Loss: -1.04e+04, Acceptance sample: 0.39, LR: 0.00088
# Step: 3400 / 5000, Loss: -9.71e+03, Acceptance sample: 0.49, LR: 0.00088
# Step: 3500 / 5000, Loss: -8.50e+03, Acceptance sample: 0.44, LR: 0.00088
# Step: 3600 / 5000, Loss: -1.08e+04, Acceptance sample: 0.42, LR: 0.00088
# Step: 3700 / 5000, Loss: -1.13e+04, Acceptance sample: 0.45, LR: 0.00088
# Step: 3800 / 5000, Loss: -1.02e+04, Acceptance sample: 0.44, LR: 0.00088
# Step: 3900 / 5000, Loss: -9.16e+03, Acceptance sample: 0.45, LR: 0.00088
# Step: 4000 / 5000, Loss: -9.68e+03, Acceptance sample: 0.44, LR: 0.00085
# Step: 4100 / 5000, Loss: -8.73e+03, Acceptance sample: 0.41, LR: 0.00085
# Step: 4200 / 5000, Loss: -8.36e+03, Acceptance sample: 0.50, LR: 0.00085
# Step: 4300 / 5000, Loss: -1.04e+04, Acceptance sample: 0.49, LR: 0.00085
# Step: 4400 / 5000, Loss: -9.86e+03, Acceptance sample: 0.44, LR: 0.00085
# Step: 4500 / 5000, Loss: -9.10e+03, Acceptance sample: 0.47, LR: 0.00085
# Step: 4600 / 5000, Loss: -1.01e+04, Acceptance sample: 0.43, LR: 0.00085
# Step: 4700 / 5000, Loss: -9.62e+03, Acceptance sample: 0.44, LR: 0.00085
# Step: 4800 / 5000, Loss: -8.79e+03, Acceptance sample: 0.46, LR: 0.00085
# Step: 4900 / 5000, Loss: -1.07e+04, Acceptance sample: 0.42, LR: 0.00085

# %% [markdown]
# After training, we generate $200$ chains for $2000$ steps for evaluation purposes.

# %%
samples = distribution.get_samples(n=n_samples)
final_samples = []

for t in range(2000):
    final_samples.append(np.copy(samples))

    feed_dict = {
        x: samples,
    }

    samples = sess.run(output[0], feed_dict)

# %% [markdown]
# We compute the HMC chains with **auto-correlation spectrums** as well.

# %%
L2HMC_samples = np.array(final_samples)
HMC_samples_1 = get_hmc_samples(2, 0.1, distribution.get_energy_function(), sess, steps=2000, samples=samples)
HMC_samples_2 = get_hmc_samples(2, 0.15, distribution.get_energy_function(), sess, steps=2000, samples=samples)
HMC_samples_3 = get_hmc_samples(2, 0.2, distribution.get_energy_function(), sess, steps=2000, samples=samples)

# %%
scale = np.sqrt(np.trace(cov))
L2HMC = acl_spectrum(L2HMC_samples, scale=scale)
HMC1 = acl_spectrum(HMC_samples_1, scale=scale)
HMC2 = acl_spectrum(HMC_samples_2, scale=scale)
HMC3 = acl_spectrum(HMC_samples_3, scale=scale)

# %% [markdown]
# We can plot auto-correlation.

# %%
xaxis = 10 * np.arange(300)
plt.plot(xaxis, L2HMC[:300], label='L2HMC')
plt.plot(xaxis, HMC1[:300], label='HMC $\epsilon=0.1$')
plt.plot(xaxis, HMC2[:300], label='HMC $\epsilon=0.15$')
plt.plot(xaxis, HMC3[:300], label='HMC $\epsilon=0.2$')
plt.ylabel('Auto-correlation')
plt.xlabel('Gradient Computations')
plt.legend()
plt.show()

# %% [markdown]
# We now compute the **Effective Sample Size** (ESS).

# %%
print 'ESS L2HMC: %.2e -- ESS HMC: %.2e -- Ratio: %d' % (ESS(L2HMC), ESS(HMC2), ESS(L2HMC) / ESS(HMC2))
# Out:
# ESS L2HMC: 2.61e-01 -- ESS HMC: 5.63e-03 -- Ratio: 46

# %% [markdown]
# We can visualize a single chain of L2HMC for $50$ time steps.

# %%
plt.scatter(S[:, 0], S[:, 1])
plt.plot(L2HMC_samples[:50, 1, 0], L2HMC_samples[:50, 1, 1], color='orange', marker='o', alpha=0.8)
plt.show()
